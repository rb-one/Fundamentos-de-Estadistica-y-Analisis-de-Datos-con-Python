# %% [markdown]
# # Visualizacion de datos usando python

# %%
import scipy.stats
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('bicicletas-compartidas.csv')

# %%
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %% [markdown]
# ## Variables Categoricas

# %%
y = df['cuartil-ano'].apply(lambda x: 'cuartil-' + str(int(x)))

# %% [markdown]
# ### Grafica de barras

# %%
figuras, axis = plt.subplots() 
axis.bar(y.value_counts().index, y.value_counts())
axis.set_xlabel('Cuartiles del año')
axis.set_ylabel('Frecuencias')
# Out:
# Text(0, 0.5, 'Frecuencias')

# %% [markdown]
# ### Usando colores

# %%
figuras, axis = plt.subplots() 
axis.bar(y.value_counts().index, y.value_counts())
axis.set_xlabel('Cuartiles del año')
axis.set_ylabel('Frecuencias')
axis.patches[0].set_facecolor('red')

# %% [markdown]
# ### Grafica circular

# %%
fig, ax = plt.subplots()
ax.pie(y.value_counts(), labels = y.value_counts().index)
ax.set_title('Diagrama de pie')
# Out:
# Text(0.5, 1.0, 'Diagrama de pie')

# %% [markdown]
# ## Variables Numericas

# %%
y = df['viento']

# %%
fig, ax= plt.subplots()
ax.hist(y, bins = 30)
#bins son las partes en que se divide el histogram
ax.set_xlabel('Viento')
ax.set_ylabel('Frecuencias')
plt.axvline(np.mean(y), c ='r', linestyle = '--', label = 'Promedio')
plt.axvline(np.mean(y)+np.std(y), c ='k', linestyle = '--', label = '+ 1-desviacion')
plt.axvline(np.mean(y)-np.std(y), c ='k', linestyle = '--', label = '- 1-desviacion')
ax.legend()
#es necesaio definir los labels para poder aplicar el legend

# %% [markdown]
# #### Boxplot basico

# %%
y = df['bicis-compartidas']
fig, ax = plt.subplots()
ax.boxplot(x = y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f77d0965b50>,
#   <matplotlib.lines.Line2D at 0x7f77d0965eb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f77d0971250>,
#   <matplotlib.lines.Line2D at 0x7f77d09715b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f77d09657f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f77d0971910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f77d0971c10>],
#  'means': []}

# %% [markdown]
# ### boxplot

# %%
y = df['bicis-compartidas']

fig, ax = plt.subplots()
sns.boxplot(x = 'cuartil-ano', y = 'bicis-compartidas', data = df)

# %% [markdown]
# ### scatterplot

# %%
fig, ax = plt.subplots()
ax.scatter( df['viento'], df['bicis-compartidas'], alpha = 0.2)
ax.set_title('Distribucion conjunta de Viento y Bicis-compartidas')
ax.set_xlabel('Viento')
ax.set_ylabel('Bicis-compartidas')
# Out:
# Text(0, 0.5, 'Bicis-compartidas')
